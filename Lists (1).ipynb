# %%
my_list = ['A','B','C','D','E']
print(my_list)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
print (my_list[0])
print (my_list[1])
print (my_list[2:])
# Out:
# A
# B
# ['C', 'D', 'E']

# %%
print (my_list[-1])
# Out:
# E

# %%
print (my_list[-3])
# Out:
# C

# %%
print (my_list[1:4])
# Out:
# ['B', 'C', 'D']

# %%
print (my_list[:-4])
# Out:
# ['A']

# %%
my_list.append('F')
print(my_list)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
my_list.pop()
print(my_list)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
my_list.pop()
print(my_list)
# Out:
# ['A', 'B', 'C', 'D']

# %%
my_list.pop(-1)
print(my_list)
# Out:
# ['A', 'B', 'C']

# %%
my_list.pop(-2)
print(my_list)
# Out:
# ['A', 'C']

# %%
my_list.append('D')
print(my_list)
# Out:
# ['A', 'C', 'D', 'D']

# %%
my_list.remove('C')
print(my_list)
# Out:
# ['A']

# %%
mystring = "Hello this is pallavi"
print(mystring)
# Out:
# Hello this is pallavi

# %%
mylist =list(mystring)
print(mylist)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 't', 'h', 'i', 's', ' ', 'i', 's', ' ', 'p', 'a', 'l', 'l', 'a', 'v', 'i']

# %%
mystring = "Hello this is pallavi"
mylist1 = mystring.split()
print(mylist1)
# Out:
# ['Hello', 'this', 'is', 'pallavi']

# %%
mystring = "Hello,this,is,pallavi"
mylist1 = mystring.split()
print(mylist1)
# Out:
# ['Hello,this,is,pallavi']

# %%
mystring = "Hello,this,is,pallavi"
mylist1 = mystring.split(',')
print(mylist1)
# Out:
# ['Hello', 'this', 'is', 'pallavi']

# %%
mystring1 = " ".join(mylist1)
print(mystring1)
# Out:
# Hello this is pallavi

# %%
mylist = ['Hi']
print (mylist*5)
# Out:
# ['Hi', 'Hi', 'Hi', 'Hi', 'Hi']

# %%
mylist1 = ['Hi']
mylist2 = ['Hello']
print (mylist1+mylist2)
# Out:
# ['Hi', 'Hello']

# %%
mylist = [1,2,3,4,5,6,7,8,9]
print (len(mylist))
# Out:
# 9

# %%
print(max(mylist))
# Out:
# 9

# %%
print(min(mylist))
# Out:
# 1

# %%
nest = [[1,2,3],[1,2,3],[1,2,3]]
print(nest)
print(nest[1])
print(nest[-1])
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
# [1, 2, 3]
# [1, 2, 3]

# %%
print(nest[0][1])
print(nest[1][2])
print(nest[2][2])
# Out:
# 2
# 3
# 3

# %%
print(nest[0:2])
# Out:
# [[1, 2, 3], [1, 2, 3]]

# %%
input_list =  [['SAS','R'],['Tableau','SQL'],['Python','Java']]
answer = input_list[2][0][0:]
print(answer)
# Out:
# Python

# %%
input_list =  [['SAS','R'],['Tableau','SQL'],['Python','Java']]
answer = input_list[2][0][0:]
print(answer)
# Out:
# Python

# %%
answer = input_list[1][0][0:]
print(answer)
# Out:
# Tableau

# %%
answer = input_list[1][0:]
print(answer)
# Out:
# ['Tableau', 'SQL']

# %%
answer = input_list[1]
print(answer)
# Out:
# ['Tableau', 'SQL']

# %%
answer = input_list[1][1:]
print(answer)
# Out:
# ['SQL']

# %%
answer = input_list[2][1:]
print(answer)
# Out:
# ['Java']

# %%
answer = input_list[2][1]
print(answer)
# Out:
# Java
